# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import io

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# %%
path = 'images/'

# %% [markdown]
# ** label detection **

# %%
# Instantiates a client
client = vision.ImageAnnotatorClient()
file_name = f'{path}test_img.png'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# hair
# facial hair
# face
# beard
# man
# glasses
# person
# facial expression
# chin
# eyebrow

# %% [markdown]
# ** text detection **

# %%
def detect_text(path):
    """Detects text in the file."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))
    return texts

# %%
file_name = f'{path}receipt.jpg'
texts = detect_text(file_name)
# Out:
# Texts:
#
# "85℃ Bakery Cafe
# 5-L Serramonte Center
# Daly City, CA 94015
# (650)992-8585
# alt
# Chk: 03745
# CD1217 CZARINA
# 0024-03
# 2018/03/22 17:00:55
# 1 Brioche
# 1 Mango Bread
# 1 Milk Pudding
# 1 85C Coffee Bread
# 1 Milk Butter Puff
# 2.75
# 2.50
# 1.85
# 3.05
# 1.95
# 12.10
# 0.00
# 12.10
# SUBTOTAL
# TOTAL
# CreditCard
# 12.10
# CHANGE
# 0.00
# VISA
# XXXXXXXXXXXX9046 12.10
# "
# bounds: (8,183),(946,183),(946,1542),(8,1542)
#
# "85"
# bounds: (228,208),(315,200),(321,276),(235,284)
#
# "℃"
# bounds: (315,200),(385,194),(391,267),(321,273)
#
# "Bakery"
# bounds: (400,218),(586,202),(590,247),(404,263)
#
# "Cafe"
# bounds: (598,195),(733,183),(737,229),(602,241)
#
# "5-L"
# bounds: (285,325),(342,320),(345,358),(288,363)
#
# "Serramonte"
# bounds: (362,324),(542,308),(546,348),(365,364)
#
# "Center"
# bounds: (562,305),(674,295),(677,333),(565,343)
#
# "Daly"
# bounds: (305,370),(381,363),(385,407),(309,414)
#
# "City,"
# bounds: (401,372),(485,365),(488,398),(404,405)
#
# "CA"
# bounds: (507,354),(544,351),(547,383),(510,386)
#
# "94015"
# bounds: (564,348),(657,340),(660,378),(567,386)
#
# "(650)992-8585"
# bounds: (369,418),(603,388),(608,426),(374,457)
#
# "alt"
# bounds: (8,379),(42,379),(42,401),(8,401)
#
# "Chk:"
# bounds: (704,485),(775,476),(780,509),(708,518)
#
# "03745"
# bounds: (800,471),(897,458),(902,494),(805,507)
#
# "CD1217"
# bounds: (140,612),(235,606),(237,640),(142,646)
#
# "CZARINA"
# bounds: (264,603),(390,595),(392,630),(266,638)
#
# "0024-03"
# bounds: (144,660),(250,649),(254,683),(148,694)
#
# "2018/03/22"
# bounds: (545,633),(731,617),(735,658),(549,674)
#
# "17:00:55"
# bounds: (755,616),(909,602),(913,639),(758,653)
#
# "1"
# bounds: (165,746),(173,746),(174,778),(166,778)
#
# "Brioche"
# bounds: (195,745),(313,740),(314,774),(196,779)
#
# "1"
# bounds: (167,792),(176,792),(177,822),(168,822)
#
# "Mango"
# bounds: (195,792),(282,788),(283,822),(196,826)
#
# "Bread"
# bounds: (300,783),(390,779),(391,812),(301,816)
#
# "1"
# bounds: (172,835),(183,835),(184,863),(173,864)
#
# "Milk"
# bounds: (201,834),(269,831),(270,864),(202,867)
#
# "Pudding"
# bounds: (287,831),(410,826),(411,863),(289,868)
#
# "1"
# bounds: (174,866),(179,866),(179,908),(174,908)
#
# "85C"
# bounds: (195,866),(252,866),(252,908),(195,908)
#
# "Coffee"
# bounds: (268,866),(376,866),(376,908),(268,908)
#
# "Bread"
# bounds: (392,866),(478,866),(478,908),(392,908)
#
# "1"
# bounds: (168,921),(176,921),(176,950),(168,950)
#
# "Milk"
# bounds: (198,915),(265,915),(265,950),(198,950)
#
# "Butter"
# bounds: (285,919),(398,919),(398,950),(285,950)
#
# "Puff"
# bounds: (417,915),(486,915),(486,948),(417,948)
#
# "2.75"
# bounds: (797,708),(877,701),(880,735),(800,742)
#
# "2.50"
# bounds: (800,758),(878,744),(884,781),(806,794)
#
# "1.85"
# bounds: (811,799),(885,799),(885,837),(811,837)
#
# "3.05"
# bounds: (809,853),(887,846),(890,881),(812,888)
#
# "1.95"
# bounds: (819,894),(896,897),(894,937),(817,934)
#
# "12.10"
# bounds: (807,1026),(911,1039),(906,1082),(802,1069)
#
# "0.00"
# bounds: (828,1083),(914,1090),(910,1128),(825,1121)
#
# "12.10"
# bounds: (812,1137),(917,1138),(917,1177),(812,1176)
#
# "SUBTOTAL"
# bounds: (178,1054),(317,1048),(318,1083),(180,1089)
#
# "TOTAL"
# bounds: (164,1138),(249,1142),(247,1178),(162,1174)
#
# "CreditCard"
# bounds: (121,1222),(327,1240),(324,1279),(118,1261)
#
# "12.10"
# bounds: (817,1245),(929,1250),(927,1292),(815,1287)
#
# "CHANGE"
# bounds: (83,1321),(214,1339),(208,1380),(77,1362)
#
# "0.00"
# bounds: (840,1367),(938,1358),(942,1403),(844,1412)
#
# "VISA"
# bounds: (20,1438),(110,1430),(115,1486),(25,1494)
#
# "XXXXXXXXXXXX9046"
# bounds: (346,1463),(733,1480),(730,1533),(344,1516)
#
# "12.10"
# bounds: (780,1482),(946,1489),(944,1542),(778,1535)

# %%
texts
# Out:
# [locale: "en"
# description: "85\342\204\203 Bakery Cafe\n5-L Serramonte Center\nDaly City, CA 94015\n(650)992-8585\nalt\nChk: 03745\nCD1217 CZARINA\n0024-03\n2018/03/22 17:00:55\n1 Brioche\n1 Mango Bread\n1 Milk Pudding\n1 85C Coffee Bread\n1 Milk Butter Puff\n2.75\n2.50\n1.85\n3.05\n1.95\n12.10\n0.00\n12.10\nSUBTOTAL\nTOTAL\nCreditCard\n12.10\nCHANGE\n0.00\nVISA\nXXXXXXXXXXXX9046 12.10\n"
# bounding_poly {
#   vertices {
#     x: 8
#     y: 183
#   }
#   vertices {
#     x: 946
#     y: 183
#   }
#   vertices {
#     x: 946
#     y: 1542
#   }
#   vertices {
#     x: 8
#     y: 1542
#   }
# }
# , description: "85"
# bounding_poly {
#   vertices {
#     x: 228
#     y: 208
#   }
#   vertices {
#     x: 315
#     y: 200
#   }
#   vertices {
#     x: 321
#     y: 276
#   }
#   vertices {
#     x: 235
#     y: 284
#   }
# }
# , description: "\342\204\203"
# bounding_poly {
#   vertices {
#     x: 315
#     y: 200
#   }
#   vertices {
#     x: 385
#     y: 194
#   }
#   vertices {
#     x: 391
#     y: 267
#   }
#   vertices {
#     x: 321
#     y: 273
#   }
# }
# , description: "Bakery"
# bounding_poly {
#   vertices {
#     x: 400
#     y: 218
#   }
#   vertices {
#     x: 586
#     y: 202
#   }
#   vertices {
#     x: 590
#     y: 247
#   }
#   vertices {
#     x: 404
#     y: 263
#   }
# }
# , description: "Cafe"
# bounding_poly {
#   vertices {
#     x: 598
#     y: 195
#   }
#   vertices {
#     x: 733
#     y: 183
#   }
#   vertices {
#     x: 737
#     y: 229
#   }
#   vertices {
#     x: 602
#     y: 241
#   }
# }
# , description: "5-L"
# bounding_poly {
#   vertices {
#     x: 285
#     y: 325
#   }
#   vertices {
#     x: 342
#     y: 320
#   }
#   vertices {
#     x: 345
#     y: 358
#   }
#   vertices {
#     x: 288
#     y: 363
#   }
# }
# , description: "Serramonte"
# bounding_poly {
#   vertices {
#     x: 362
#     y: 324
#   }
#   vertices {
#     x: 542
#     y: 308
#   }
#   vertices {
#     x: 546
#     y: 348
#   }
#   vertices {
#     x: 365
#     y: 364
#   }
# }
# , description: "Center"
# bounding_poly {
#   vertices {
#     x: 562
#     y: 305
#   }
#   vertices {
#     x: 674
#     y: 295
#   }
#   vertices {
#     x: 677
#     y: 333
#   }
#   vertices {
#     x: 565
#     y: 343
#   }
# }
# , description: "Daly"
# bounding_poly {
#   vertices {
#     x: 305
#     y: 370
#   }
#   vertices {
#     x: 381
#     y: 363
#   }
#   vertices {
#     x: 385
#     y: 407
#   }
#   vertices {
#     x: 309
#     y: 414
#   }
# }
# , description: "City,"
# bounding_poly {
#   vertices {
#     x: 401
#     y: 372
#   }
#   vertices {
#     x: 485
#     y: 365
#   }
#   vertices {
#     x: 488
#     y: 398
#   }
#   vertices {
#     x: 404
#     y: 405
#   }
# }
# , description: "CA"
# bounding_poly {
#   vertices {
#     x: 507
#     y: 354
#   }
#   vertices {
#     x: 544
#     y: 351
#   }
#   vertices {
#     x: 547
#     y: 383
#   }
#   vertices {
#     x: 510
#     y: 386
#   }
# }
# , description: "94015"
# bounding_poly {
#   vertices {
#     x: 564
#     y: 348
#   }
#   vertices {
#     x: 657
#     y: 340
#   }
#   vertices {
#     x: 660
#     y: 378
#   }
#   vertices {
#     x: 567
#     y: 386
#   }
# }
# , description: "(650)992-8585"
# bounding_poly {
#   vertices {
#     x: 369
#     y: 418
#   }
#   vertices {
#     x: 603
#     y: 388
#   }
#   vertices {
#     x: 608
#     y: 426
#   }
#   vertices {
#     x: 374
#     y: 457
#   }
# }
# , description: "alt"
# bounding_poly {
#   vertices {
#     x: 8
#     y: 379
#   }
#   vertices {
#     x: 42
#     y: 379
#   }
#   vertices {
#     x: 42
#     y: 401
#   }
#   vertices {
#     x: 8
#     y: 401
#   }
# }
# , description: "Chk:"
# bounding_poly {
#   vertices {
#     x: 704
#     y: 485
#   }
#   vertices {
#     x: 775
#     y: 476
#   }
#   vertices {
#     x: 780
#     y: 509
#   }
#   vertices {
#     x: 708
#     y: 518
#   }
# }
# , description: "03745"
# bounding_poly {
#   vertices {
#     x: 800
#     y: 471
#   }
#   vertices {
#     x: 897
#     y: 458
#   }
#   vertices {
#     x: 902
#     y: 494
#   }
#   vertices {
#     x: 805
#     y: 507
#   }
# }
# , description: "CD1217"
# bounding_poly {
#   vertices {
#     x: 140
#     y: 612
#   }
#   vertices {
#     x: 235
#     y: 606
#   }
#   vertices {
#     x: 237
#     y: 640
#   }
#   vertices {
#     x: 142
#     y: 646
#   }
# }
# , description: "CZARINA"
# bounding_poly {
#   vertices {
#     x: 264
#     y: 603
#   }
#   vertices {
#     x: 390
#     y: 595
#   }
#   vertices {
#     x: 392
#     y: 630
#   }
#   vertices {
#     x: 266
#     y: 638
#   }
# }
# , description: "0024-03"
# bounding_poly {
#   vertices {
#     x: 144
#     y: 660
#   }
#   vertices {
#     x: 250
#     y: 649
#   }
#   vertices {
#     x: 254
#     y: 683
#   }
#   vertices {
#     x: 148
#     y: 694
#   }
# }
# , description: "2018/03/22"
# bounding_poly {
#   vertices {
#     x: 545
#     y: 633
#   }
#   vertices {
#     x: 731
#     y: 617
#   }
#   vertices {
#     x: 735
#     y: 658
#   }
#   vertices {
#     x: 549
#     y: 674
#   }
# }
# , description: "17:00:55"
# bounding_poly {
#   vertices {
#     x: 755
#     y: 616
#   }
#   vertices {
#     x: 909
#     y: 602
#   }
#   vertices {
#     x: 913
#     y: 639
#   }
#   vertices {
#     x: 758
#     y: 653
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 165
#     y: 746
#   }
#   vertices {
#     x: 173
#     y: 746
#   }
#   vertices {
#     x: 174
#     y: 778
#   }
#   vertices {
#     x: 166
#     y: 778
#   }
# }
# , description: "Brioche"
# bounding_poly {
#   vertices {
#     x: 195
#     y: 745
#   }
#   vertices {
#     x: 313
#     y: 740
#   }
#   vertices {
#     x: 314
#     y: 774
#   }
#   vertices {
#     x: 196
#     y: 779
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 167
#     y: 792
#   }
#   vertices {
#     x: 176
#     y: 792
#   }
#   vertices {
#     x: 177
#     y: 822
#   }
#   vertices {
#     x: 168
#     y: 822
#   }
# }
# , description: "Mango"
# bounding_poly {
#   vertices {
#     x: 195
#     y: 792
#   }
#   vertices {
#     x: 282
#     y: 788
#   }
#   vertices {
#     x: 283
#     y: 822
#   }
#   vertices {
#     x: 196
#     y: 826
#   }
# }
# , description: "Bread"
# bounding_poly {
#   vertices {
#     x: 300
#     y: 783
#   }
#   vertices {
#     x: 390
#     y: 779
#   }
#   vertices {
#     x: 391
#     y: 812
#   }
#   vertices {
#     x: 301
#     y: 816
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 172
#     y: 835
#   }
#   vertices {
#     x: 183
#     y: 835
#   }
#   vertices {
#     x: 184
#     y: 863
#   }
#   vertices {
#     x: 173
#     y: 864
#   }
# }
# , description: "Milk"
# bounding_poly {
#   vertices {
#     x: 201
#     y: 834
#   }
#   vertices {
#     x: 269
#     y: 831
#   }
#   vertices {
#     x: 270
#     y: 864
#   }
#   vertices {
#     x: 202
#     y: 867
#   }
# }
# , description: "Pudding"
# bounding_poly {
#   vertices {
#     x: 287
#     y: 831
#   }
#   vertices {
#     x: 410
#     y: 826
#   }
#   vertices {
#     x: 411
#     y: 863
#   }
#   vertices {
#     x: 289
#     y: 868
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 174
#     y: 866
#   }
#   vertices {
#     x: 179
#     y: 866
#   }
#   vertices {
#     x: 179
#     y: 908
#   }
#   vertices {
#     x: 174
#     y: 908
#   }
# }
# , description: "85C"
# bounding_poly {
#   vertices {
#     x: 195
#     y: 866
#   }
#   vertices {
#     x: 252
#     y: 866
#   }
#   vertices {
#     x: 252
#     y: 908
#   }
#   vertices {
#     x: 195
#     y: 908
#   }
# }
# , description: "Coffee"
# bounding_poly {
#   vertices {
#     x: 268
#     y: 866
#   }
#   vertices {
#     x: 376
#     y: 866
#   }
#   vertices {
#     x: 376
#     y: 908
#   }
#   vertices {
#     x: 268
#     y: 908
#   }
# }
# , description: "Bread"
# bounding_poly {
#   vertices {
#     x: 392
#     y: 866
#   }
#   vertices {
#     x: 478
#     y: 866
#   }
#   vertices {
#     x: 478
#     y: 908
#   }
#   vertices {
#     x: 392
#     y: 908
#   }
# }
# , description: "1"
# bounding_poly {
#   vertices {
#     x: 168
#     y: 921
#   }
#   vertices {
#     x: 176
#     y: 921
#   }
#   vertices {
#     x: 176
#     y: 950
#   }
#   vertices {
#     x: 168
#     y: 950
#   }
# }
# , description: "Milk"
# bounding_poly {
#   vertices {
#     x: 198
#     y: 915
#   }
#   vertices {
#     x: 265
#     y: 915
#   }
#   vertices {
#     x: 265
#     y: 950
#   }
#   vertices {
#     x: 198
#     y: 950
#   }
# }
# , description: "Butter"
# bounding_poly {
#   vertices {
#     x: 285
#     y: 919
#   }
#   vertices {
#     x: 398
#     y: 919
#   }
#   vertices {
#     x: 398
#     y: 950
#   }
#   vertices {
#     x: 285
#     y: 950
#   }
# }
# , description: "Puff"
# bounding_poly {
#   vertices {
#     x: 417
#     y: 915
#   }
#   vertices {
#     x: 486
#     y: 915
#   }
#   vertices {
#     x: 486
#     y: 948
#   }
#   vertices {
#     x: 417
#     y: 948
#   }
# }
# , description: "2.75"
# bounding_poly {
#   vertices {
#     x: 797
#     y: 708
#   }
#   vertices {
#     x: 877
#     y: 701
#   }
#   vertices {
#     x: 880
#     y: 735
#   }
#   vertices {
#     x: 800
#     y: 742
#   }
# }
# , description: "2.50"
# bounding_poly {
#   vertices {
#     x: 800
#     y: 758
#   }
#   vertices {
#     x: 878
#     y: 744
#   }
#   vertices {
#     x: 884
#     y: 781
#   }
#   vertices {
#     x: 806
#     y: 794
#   }
# }
# , description: "1.85"
# bounding_poly {
#   vertices {
#     x: 811
#     y: 799
#   }
#   vertices {
#     x: 885
#     y: 799
#   }
#   vertices {
#     x: 885
#     y: 837
#   }
#   vertices {
#     x: 811
#     y: 837
#   }
# }
# , description: "3.05"
# bounding_poly {
#   vertices {
#     x: 809
#     y: 853
#   }
#   vertices {
#     x: 887
#     y: 846
#   }
#   vertices {
#     x: 890
#     y: 881
#   }
#   vertices {
#     x: 812
#     y: 888
#   }
# }
# , description: "1.95"
# bounding_poly {
#   vertices {
#     x: 819
#     y: 894
#   }
#   vertices {
#     x: 896
#     y: 897
#   }
#   vertices {
#     x: 894
#     y: 937
#   }
#   vertices {
#     x: 817
#     y: 934
#   }
# }
# , description: "12.10"
# bounding_poly {
#   vertices {
#     x: 807
#     y: 1026
#   }
#   vertices {
#     x: 911
#     y: 1039
#   }
#   vertices {
#     x: 906
#     y: 1082
#   }
#   vertices {
#     x: 802
#     y: 1069
#   }
# }
# , description: "0.00"
# bounding_poly {
#   vertices {
#     x: 828
#     y: 1083
#   }
#   vertices {
#     x: 914
#     y: 1090
#   }
#   vertices {
#     x: 910
#     y: 1128
#   }
#   vertices {
#     x: 825
#     y: 1121
#   }
# }
# , description: "12.10"
# bounding_poly {
#   vertices {
#     x: 812
#     y: 1137
#   }
#   vertices {
#     x: 917
#     y: 1138
#   }
#   vertices {
#     x: 917
#     y: 1177
#   }
#   vertices {
#     x: 812
#     y: 1176
#   }
# }
# , description: "SUBTOTAL"
# bounding_poly {
#   vertices {
#     x: 178
#     y: 1054
#   }
#   vertices {
#     x: 317
#     y: 1048
#   }
#   vertices {
#     x: 318
#     y: 1083
#   }
#   vertices {
#     x: 180
#     y: 1089
#   }
# }
# , description: "TOTAL"
# bounding_poly {
#   vertices {
#     x: 164
#     y: 1138
#   }
#   vertices {
#     x: 249
#     y: 1142
#   }
#   vertices {
#     x: 247
#     y: 1178
#   }
#   vertices {
#     x: 162
#     y: 1174
#   }
# }
# , description: "CreditCard"
# bounding_poly {
#   vertices {
#     x: 121
#     y: 1222
#   }
#   vertices {
#     x: 327
#     y: 1240
#   }
#   vertices {
#     x: 324
#     y: 1279
#   }
#   vertices {
#     x: 118
#     y: 1261
#   }
# }
# , description: "12.10"
# bounding_poly {
#   vertices {
#     x: 817
#     y: 1245
#   }
#   vertices {
#     x: 929
#     y: 1250
#   }
#   vertices {
#     x: 927
#     y: 1292
#   }
#   vertices {
#     x: 815
#     y: 1287
#   }
# }
# , description: "CHANGE"
# bounding_poly {
#   vertices {
#     x: 83
#     y: 1321
#   }
#   vertices {
#     x: 214
#     y: 1339
#   }
#   vertices {
#     x: 208
#     y: 1380
#   }
#   vertices {
#     x: 77
#     y: 1362
#   }
# }
# , description: "0.00"
# bounding_poly {
#   vertices {
#     x: 840
#     y: 1367
#   }
#   vertices {
#     x: 938
#     y: 1358
#   }
#   vertices {
#     x: 942
#     y: 1403
#   }
#   vertices {
#     x: 844
#     y: 1412
#   }
# }
# , description: "VISA"
# bounding_poly {
#   vertices {
#     x: 20
#     y: 1438
#   }
#   vertices {
#     x: 110
#     y: 1430
#   }
#   vertices {
#     x: 115
#     y: 1486
#   }
#   vertices {
#     x: 25
#     y: 1494
#   }
# }
# , description: "XXXXXXXXXXXX9046"
# bounding_poly {
#   vertices {
#     x: 346
#     y: 1463
#   }
#   vertices {
#     x: 733
#     y: 1480
#   }
#   vertices {
#     x: 730
#     y: 1533
#   }
#   vertices {
#     x: 344
#     y: 1516
#   }
# }
# , description: "12.10"
# bounding_poly {
#   vertices {
#     x: 780
#     y: 1482
#   }
#   vertices {
#     x: 946
#     y: 1489
#   }
#   vertices {
#     x: 944
#     y: 1542
#   }
#   vertices {
#     x: 778
#     y: 1535
#   }
# }
# ]

# %% [markdown]
# ** use url **

# %%
def detect_text_uri(uri):
    """Detects text in the file located in Google Cloud Storage or on the Web.
    """
    client = vision.ImageAnnotatorClient()
    image = types.Image()
    image.source.image_uri = uri

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))
    
    return texts

# %%
url = 'https://dvidr.s3.amazonaws.com/85c.jpg?Signature=TNQbX0ndlcmvo4d2g%2F3FXbPonwE%3D&Expires=1523662875&AWSAccessKeyId=AKIAJ4FD4JXF5A7AKGGA'

# %%
texts = detect_text_uri(url)
# Out:
# Texts:
#
# "859
# 85 C Bakery Cafe
# 5-L Serramonte Center
# Daly City, CA 94015
# (650)992-8585
# Chk: 03745
# 2
# To Go
# CD1217 CZARINA
# 0024-03
# 2018/03/22 17:00:55
# 1 Brioche
# 1 Mango Bread
# 1 Milk Pudding
# 1 85C Coffee Bread
# 1 Milk Butter Puff
# 2.75
# 2.50
# 1.85
# 3.05
# 1.95
# SUBTOTAL
# TAX
# OTAL
# 12.10
# 0.00
# 12.10
# CreditCard
# 12.10
# 0.00
# XXXXXXXXXXXX9046 12.10
# CHANGE
# 2
# "
# bounds: (0,17),(854,17),(854,1542),(0,1542)
#
# "859"
# bounds: (303,33),(488,17),(496,110),(311,127)
#
# "85"
# bounds: (145,203),(236,199),(239,277),(148,281)
#
# "C"
# bounds: (237,199),(279,197),(282,275),(240,277)
#
# "Bakery"
# bounds: (317,213),(502,205),(504,255),(319,263)
#
# "Cafe"
# bounds: (516,192),(652,186),(654,228),(518,234)
#
# "5-L"
# bounds: (202,325),(258,320),(261,358),(205,363)
#
# "Serramonte"
# bounds: (278,323),(457,307),(461,348),(282,364)
#
# "Center"
# bounds: (478,305),(591,295),(594,333),(481,343)
#
# "Daly"
# bounds: (222,370),(298,363),(302,407),(226,414)
#
# "City,"
# bounds: (318,372),(402,365),(405,398),(321,405)
#
# "CA"
# bounds: (424,354),(461,351),(464,383),(427,386)
#
# "94015"
# bounds: (481,348),(574,340),(577,378),(484,386)
#
# "(650)992-8585"
# bounds: (286,419),(518,388),(523,424),(291,456)
#
# "Chk:"
# bounds: (621,486),(692,477),(696,509),(625,518)
#
# "03745"
# bounds: (718,471),(814,459),(819,495),(723,508)
#
# "2"
# bounds: (765,467),(775,467),(776,499),(766,499)
#
# "To"
# bounds: (49,522),(79,522),(79,553),(49,553)
#
# "Go"
# bounds: (94,517),(128,517),(128,549),(94,549)
#
# "CD1217"
# bounds: (57,612),(152,606),(154,640),(59,646)
#
# "CZARINA"
# bounds: (180,603),(306,595),(308,630),(182,638)
#
# "0024-03"
# bounds: (63,659),(168,650),(170,682),(66,691)
#
# "2018/03/22"
# bounds: (461,632),(649,616),(653,656),(465,673)
#
# "17:00:55"
# bounds: (673,614),(826,601),(830,637),(676,651)
#
# "1"
# bounds: (82,746),(89,746),(90,778),(83,778)
#
# "Brioche"
# bounds: (112,745),(229,740),(230,773),(113,778)
#
# "1"
# bounds: (83,793),(92,792),(94,822),(85,823)
#
# "Mango"
# bounds: (112,793),(198,788),(200,822),(114,827)
#
# "Bread"
# bounds: (216,785),(307,780),(309,813),(218,818)
#
# "1"
# bounds: (90,835),(101,835),(101,865),(90,865)
#
# "Milk"
# bounds: (120,832),(186,831),(186,864),(120,865)
#
# "Pudding"
# bounds: (205,829),(329,828),(329,864),(205,865)
#
# "1"
# bounds: (90,879),(99,879),(99,908),(90,908)
#
# "85C"
# bounds: (119,877),(172,877),(172,906),(119,906)
#
# "Coffee"
# bounds: (189,874),(296,874),(296,906),(189,906)
#
# "Bread"
# bounds: (314,870),(403,870),(403,905),(314,905)
#
# "1"
# bounds: (82,921),(92,921),(92,950),(82,950)
#
# "Milk"
# bounds: (114,915),(180,915),(180,950),(114,950)
#
# "Butter"
# bounds: (201,919),(314,919),(314,950),(201,950)
#
# "Puff"
# bounds: (333,915),(402,915),(402,948),(333,948)
#
# "2.75"
# bounds: (714,708),(795,701),(798,736),(717,743)
#
# "2.50"
# bounds: (720,751),(799,751),(799,789),(720,789)
#
# "1.85"
# bounds: (726,804),(800,798),(803,831),(729,838)
#
# "3.05"
# bounds: (726,853),(804,846),(807,882),(729,889)
#
# "1.95"
# bounds: (736,894),(813,897),(811,937),(734,934)
#
# "SUBTOTAL"
# bounds: (94,1055),(237,1047),(239,1084),(96,1092)
#
# "TAX"
# bounds: (90,1100),(141,1096),(144,1127),(93,1132)
#
# "OTAL"
# bounds: (80,1142),(158,1139),(160,1180),(82,1183)
#
# "12.10"
# bounds: (723,1034),(826,1038),(824,1074),(722,1070)
#
# "0.00"
# bounds: (744,1084),(831,1092),(827,1128),(741,1121)
#
# "12.10"
# bounds: (728,1136),(835,1141),(833,1180),(726,1175)
#
# "CreditCard"
# bounds: (37,1222),(244,1240),(241,1279),(34,1261)
#
# "12.10"
# bounds: (734,1247),(844,1247),(844,1289),(734,1289)
#
# "0.00"
# bounds: (758,1363),(854,1362),(854,1404),(758,1405)
#
# "XXXXXXXXXXXX9046"
# bounds: (263,1463),(650,1480),(647,1533),(261,1516)
#
# "12.10"
# bounds: (697,1482),(854,1489),(852,1542),(695,1535)
#
# "CHANGE"
# bounds: (5,1324),(131,1340),(126,1379),(0,1363)
#
# "2"
# bounds: (562,1435),(576,1436),(572,1531),(558,1530)

# %% [markdown]
# ** add bounding box on image **

# %%
from skimage import io
img = io.imread(url)

# %%
img.shape
# Out:
# (1600, 916, 3)

# %% [markdown]
# The “imread” function reads the images in RGB format.

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
import cv2
def bounding_box(url, texts):
    img = io.imread(url)    # read image from url
    for text in texts[1:]:  # 0th bounding box is whole picture
        vertices = [(vertex.x, vertex.y)
                for vertex in text.bounding_poly.vertices]   # get coordinates
        cv2.polylines(img, [np.array(vertices)], True, (0,255,0), 2)  # plot line

    plt.figure(figsize=(10,10))
    plt.imshow(img)

# %%
bounding_box(url, texts)

# %%
print(texts[0].description)
# Out:
# 859
# 85 C Bakery Cafe
# 5-L Serramonte Center
# Daly City, CA 94015
# (650)992-8585
# Chk: 03745
# 2
# To Go
# CD1217 CZARINA
# 0024-03
# 2018/03/22 17:00:55
# 1 Brioche
# 1 Mango Bread
# 1 Milk Pudding
# 1 85C Coffee Bread
# 1 Milk Butter Puff
# 2.75
# 2.50
# 1.85
# 3.05
# 1.95
# SUBTOTAL
# TAX
# OTAL
# 12.10
# 0.00
# 12.10
# CreditCard
# 12.10
# 0.00
# XXXXXXXXXXXX9046 12.10
# CHANGE
# 2

# %%
import re
re.findall(r'\n(\d+\.\d{2})\n', texts[0].description)
# Out:
# ['2.75', '1.85', '1.95', '12.10', '12.10', '12.10']

# %%
url2 = 'http://www.receipt-template.net/wp-content/uploads/2012/05/restaurant-receipt.jpg'

# %%
texts2 = detect_text_uri(url2)
# Out:
# Texts:
#
# "Restaurant Name
# Address 1
# Address 2
# 3/15/12 6:06:44 PM
# Tbl: 201 Sec: S1 Guest: 1
# Server: John
# Chk: #1 1 1 1
# 5 BLOODY MARY $40.75
# 1 FRESH OYSTER $12.50
# SUBTOTAL $53.25
# TAX $5.33
# GRATUITY $6.00
# TOTAL $64.60
# Thank You for Dining With Us!
# Please Come Again
# "
# bounds: (45,93),(321,93),(321,490),(45,490)
#
# "Restaurant"
# bounds: (138,93),(207,93),(207,103),(138,103)
#
# "Name"
# bounds: (213,93),(252,93),(252,103),(213,103)
#
# "Address"
# bounds: (161,110),(214,110),(214,121),(161,121)
#
# "1"
# bounds: (220,110),(224,110),(224,121),(220,121)
#
# "Address"
# bounds: (161,127),(214,127),(214,138),(161,138)
#
# "2"
# bounds: (219,127),(226,127),(226,138),(219,138)
#
# "3/15/12"
# bounds: (46,180),(92,180),(92,191),(46,191)
#
# "6:06:44"
# bounds: (98,180),(145,180),(145,190),(98,190)
#
# "PM"
# bounds: (151,180),(171,180),(171,190),(151,190)
#
# "Tbl"
# bounds: (45,199),(65,199),(65,210),(45,210)
#
# ":"
# bounds: (66,199),(68,199),(68,210),(66,210)
#
# "201"
# bounds: (73,199),(95,199),(95,210),(73,210)
#
# "Sec"
# bounds: (102,199),(124,199),(124,210),(102,210)
#
# ":"
# bounds: (125,202),(130,202),(130,210),(125,210)
#
# "S1"
# bounds: (135,199),(150,199),(150,210),(135,210)
#
# "Guest"
# bounds: (162,199),(200,199),(200,210),(162,210)
#
# ":"
# bounds: (201,202),(203,202),(203,210),(201,210)
#
# "1"
# bounds: (209,199),(213,199),(213,210),(209,210)
#
# "Server:"
# bounds: (239,180),(286,180),(286,191),(239,191)
#
# "John"
# bounds: (292,180),(320,180),(320,190),(292,190)
#
# "Chk"
# bounds: (239,199),(265,199),(265,211),(239,211)
#
# ":"
# bounds: (266,199),(271,199),(271,211),(266,211)
#
# "#"
# bounds: (279,199),(288,199),(288,210),(279,210)
#
# "1"
# bounds: (289,199),(294,199),(294,211),(289,211)
#
# "1"
# bounds: (298,199),(303,199),(303,211),(298,211)
#
# "1"
# bounds: (307,199),(312,199),(312,211),(307,211)
#
# "1"
# bounds: (316,199),(321,199),(321,211),(316,211)
#
# "5"
# bounds: (104,254),(110,254),(110,265),(104,265)
#
# "BLOODY"
# bounds: (115,254),(176,254),(176,265),(115,265)
#
# "MARY"
# bounds: (181,254),(223,254),(223,265),(181,265)
#
# "$40.75"
# bounds: (239,253),(284,253),(284,265),(239,265)
#
# "1"
# bounds: (99,273),(102,273),(102,284),(99,284)
#
# "FRESH"
# bounds: (109,273),(158,273),(158,284),(109,284)
#
# "OYSTER"
# bounds: (163,273),(223,273),(223,284),(163,284)
#
# "$12.50"
# bounds: (238,272),(284,272),(284,284),(238,284)
#
# "SUBTOTAL"
# bounds: (145,330),(224,330),(224,341),(145,341)
#
# "$53.25"
# bounds: (239,329),(284,329),(284,341),(239,341)
#
# "TAX"
# bounds: (195,348),(221,348),(221,363),(195,363)
#
# "$5.33"
# bounds: (233,348),(274,348),(274,363),(233,363)
#
# "GRATUITY"
# bounds: (149,368),(223,368),(223,379),(149,379)
#
# "$6.00"
# bounds: (238,368),(276,368),(276,380),(238,380)
#
# "TOTAL"
# bounds: (176,388),(224,388),(224,399),(176,399)
#
# "$64.60"
# bounds: (239,387),(284,387),(284,399),(239,399)
#
# "Thank"
# bounds: (96,459),(135,459),(135,469),(96,469)
#
# "You"
# bounds: (139,459),(165,459),(165,469),(139,469)
#
# "for"
# bounds: (171,459),(187,459),(187,469),(171,469)
#
# "Dining"
# bounds: (193,459),(232,459),(232,472),(193,472)
#
# "With"
# bounds: (237,459),(265,459),(265,469),(237,469)
#
# "Us!"
# bounds: (270,459),(290,459),(290,469),(270,469)
#
# "Please"
# bounds: (131,476),(173,476),(173,487),(131,487)
#
# "Come"
# bounds: (178,476),(217,476),(217,487),(178,487)
#
# "Again"
# bounds: (221,476),(258,476),(258,490),(221,490)

# %%
bounding_box(url2, texts2)

# %%
print(texts2[0].description)
# Out:
# Walmart
# Save money. Live better.
# HANAGER IRENE BROWN
# 360) 532 - 7595
# ST# 2037 OP# 00003048 TE# 18 TR# 05704
# 1.68 0
# 1.68 0
# 0.76 N
# 1.28 N
# 3.08 0
# 1.82 0
# HALF HALF 060538818716 F
# HALF HALF 060538818716 F
# GV BRWN RICE 007874212222F
# GV LONG RICE 007874235205 F
# GU 2 RF MLK 007874235187 F
# RAMEN-BEEF12 004178900232 F
# SUBTOTAL
# TOTAL
# SHOPPING CARD TEND
# CASH TEND
# CHANGE DUE
# 10.30
# 10.30
# 10.00
# 0.50
# 0.20
# 10.00
# SHOP.CARD REDEMPTION
# ACCOUNT 605214515600
# APPR. CODE = 037453
# REF #0571931
# Beg Bal Tran Ant End Bal
# 0.00
# 0.00
# 10.00
# 10/14/10 21:20:50
# # ITEMS SOLD 6
# TC# 5803 0268 1908 2233 6122
# Washington E-Cycles: Free Recycling
# For Computers, Monitors, and TV's
# www.ecyclewashington.org 1-800-RECYCLE
# THANK YOU FOR SHOPPING WITH US
# 10/14/10 21:20:58

# %% [markdown]
# ** try document text detection **

# %%
def detect_document_uri(uri):
    """Detects document features in the file located in Google Cloud
    Storage or web."""
    client = vision.ImageAnnotatorClient()
    image = types.Image()
    image.source.image_uri = uri

    response = client.document_text_detection(image=image)
    document = response.full_text_annotation

    for page in document.pages:
        for block in page.blocks:
            block_words = []
            for paragraph in block.paragraphs:
                block_words.extend(paragraph.words)

            block_symbols = []
            for word in block_words:
                block_symbols.extend(word.symbols)

            block_text = ''
            for symbol in block_symbols:
                block_text = block_text + symbol.text

            print('Block Content: {}'.format(block_text))
            print('Block Bounds:\n {}'.format(block.bounding_box))

# %%
detect_document_uri(url)
# Out:
# Block Content: 85
# Block Bounds:
#  vertices {
#   x: 284
#   y: 30
# }
# vertices {
#   x: 389
#   y: 7
# }
# vertices {
#   x: 413
#   y: 121
# }
# vertices {
#   x: 309
#   y: 143
# }
#
# Block Content: 85°CBakeryCafe
# Block Bounds:
#  vertices {
#   x: 135
#   y: 198
# }
# vertices {
#   x: 627
#   y: 171
# }
# vertices {
#   x: 632
#   y: 253
# }
# vertices {
#   x: 139
#   y: 280
# }
#
# Block Content: 5-LSerramonteCenterDalyCity,CA94015(650)992-8585
# Block Bounds:
#  vertices {
#   x: 199
#   y: 325
# }
# vertices {
#   x: 580
#   y: 286
# }
# vertices {
#   x: 595
#   y: 431
# }
# vertices {
#   x: 214
#   y: 469
# }
#
# Block Content: ToGo
# Block Bounds:
#  vertices {
#   x: 45
#   y: 519
# }
# vertices {
#   x: 119
#   y: 510
# }
# vertices {
#   x: 124
#   y: 551
# }
# vertices {
#   x: 50
#   y: 560
# }
#
# Block Content: Chk:03745EEEEEEE========
# Block Bounds:
#  vertices {
#   x: 502
#   y: 484
# }
# vertices {
#   x: 807
#   y: 454
# }
# vertices {
#   x: 817
#   y: 545
# }
# vertices {
#   x: 511
#   y: 576
# }
#
# Block Content: =
# Block Bounds:
#  vertices {
#   x: 366
#   y: 551
# }
# vertices {
#   x: 367
#   y: 551
# }
# vertices {
#   x: 371
#   y: 578
# }
# vertices {
#   x: 370
#   y: 578
# }
#
# Block Content: =
# Block Bounds:
#  vertices {
#   x: 404
#   y: 547
# }
# vertices {
#   x: 405
#   y: 547
# }
# vertices {
#   x: 405
#   y: 572
# }
# vertices {
#   x: 404
#   y: 572
# }
#
# Block Content: 2018/03/2217:00:55---========
# Block Bounds:
#  vertices {
#   x: 465
#   y: 625
# }
# vertices {
#   x: 821
#   y: 599
# }
# vertices {
#   x: 827
#   y: 685
# }
# vertices {
#   x: 471
#   y: 712
# }
#
# Block Content: IL
# Block Bounds:
#  vertices {
#   x: 794
#   y: 682
# }
# vertices {
#   x: 792
#   y: 665
# }
# vertices {
#   x: 811
#   y: 663
# }
# vertices {
#   x: 813
#   y: 680
# }
#
# Block Content: ==============CD1217CZARINA0024-03========1Brioche1MangoBread1MilkPudding185CCoffeeBread1MilkButterPuff
# Block Bounds:
#  vertices {
#   x: 50
#   y: 564
# }
# vertices {
#   x: 391
#   y: 548
# }
# vertices {
#   x: 409
#   y: 955
# }
# vertices {
#   x: 69
#   y: 971
# }
#
# Block Content: 2.752.501.85
# Block Bounds:
#  vertices {
#   x: 717
#   y: 699
# }
# vertices {
#   x: 795
#   y: 699
# }
# vertices {
#   x: 795
#   y: 841
# }
# vertices {
#   x: 717
#   y: 841
# }
#
# Block Content: 3.05
# Block Bounds:
#  vertices {
#   x: 724
#   y: 844
# }
# vertices {
#   x: 800
#   y: 837
# }
# vertices {
#   x: 804
#   y: 881
# }
# vertices {
#   x: 728
#   y: 888
# }
#
# Block Content: 1.95
# Block Bounds:
#  vertices {
#   x: 733
#   y: 892
# }
# vertices {
#   x: 805
#   y: 892
# }
# vertices {
#   x: 805
#   y: 939
# }
# vertices {
#   x: 733
#   y: 939
# }
#
# Block Content: SUBTOTALTAXTOTAL
# Block Bounds:
#  vertices {
#   x: 75
#   y: 1047
# }
# vertices {
#   x: 230
#   y: 1047
# }
# vertices {
#   x: 230
#   y: 1177
# }
# vertices {
#   x: 75
#   y: 1177
# }
#
# Block Content: 12.100.0012.10
# Block Bounds:
#  vertices {
#   x: 723
#   y: 1032
# }
# vertices {
#   x: 830
#   y: 1036
# }
# vertices {
#   x: 825
#   y: 1187
# }
# vertices {
#   x: 718
#   y: 1183
# }
#
# Block Content: -
# Block Bounds:
#  vertices {
#   x: 530
#   y: 1200
# }
# vertices {
#   x: 532
#   y: 1200
# }
# vertices {
#   x: 532
#   y: 1224
# }
# vertices {
#   x: 530
#   y: 1224
# }
#
# Block Content: CreditCard
# Block Bounds:
#  vertices {
#   x: 31
#   y: 1213
# }
# vertices {
#   x: 238
#   y: 1229
# }
# vertices {
#   x: 234
#   y: 1288
# }
# vertices {
#   x: 26
#   y: 1272
# }
#
# Block Content: 12.10
# Block Bounds:
#  vertices {
#   x: 735
#   y: 1242
# }
# vertices {
#   x: 836
#   y: 1242
# }
# vertices {
#   x: 836
#   y: 1296
# }
# vertices {
#   x: 735
#   y: 1296
# }
#
# Block Content: CHANGE
# Block Bounds:
#  vertices {
#   x: -5
#   y: 1316
# }
# vertices {
#   x: 120
#   y: 1316
# }
# vertices {
#   x: 120
#   y: 1383
# }
# vertices {
#   x: -5
#   y: 1383
# }
#
# Block Content: 0.00
# Block Bounds:
#  vertices {
#   x: 756
#   y: 1350
# }
# vertices {
#   x: 843
#   y: 1350
# }
# vertices {
#   x: 843
#   y: 1413
# }
# vertices {
#   x: 756
#   y: 1413
# }
#
# Block Content: XXXXXXXXXXXX9046
# Block Bounds:
#  vertices {
#   x: 267
#   y: 1457
# }
# vertices {
#   x: 648
#   y: 1471
# }
# vertices {
#   x: 645
#   y: 1541
# }
# vertices {
#   x: 264
#   y: 1527
# }
#
# Block Content: 12.10
# Block Bounds:
#  vertices {
#   x: 743
#   y: 1475
# }
# vertices {
#   x: 858
#   y: 1479
# }
# vertices {
#   x: 855
#   y: 1549
# }
# vertices {
#   x: 740
#   y: 1545
# }
